# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
data = pd.read_csv("D:\lina_lau\C339_datafundamentals\data_analysis_project\database_datasets\owid-co2-data.csv")

# %%
data
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3769828.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3787706.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3806634.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3825655.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 46518     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 46519     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 46520     Zimbabwe  2019      ZWE  15354606.0           NaN       0.570
# 46521     Zimbabwe  2020      ZWE  15669663.0           NaN       0.570
# 46522     Zimbabwe  2021      ZWE  15993525.0           NaN       0.570
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
data.columns

# %%
# Data preprocessing:
# Fill NAs with zeros:
data = data.fillna(0)

# Create GDP per capita column:
data['gdp_per_capita'] = np.where(data['population']!= 0, data['gdp']/data['population'], 0)

# %%
# Make dataframe pipeline interactive:
idf = data.interactive()

# %%
# Define panel widgets:
year_slider = pn.widgets.IntSlider(name = 'Year Slider', start = 1750, end = 2020, step = 5, value = 1850)
year_slider
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# c:\ProgramData\Anaconda3\lib\site-packages\panel\viewable.py in _repr_mimebundle_(self, include, exclude)
#     621
#     622         if config.comms in ('vscode', 'ipywidgets'):
# --> 623             widget = ipywidget(self)
#     624             if hasattr(widget, '_repr_mimebundle_'):
#     625                 return widget._repr_mimebundle_(include=include, exclude=exclude), {}
#
# c:\ProgramData\Anaconda3\lib\site-packages\panel\io\notebook.py in ipywidget(obj, **kwargs)
# ...
